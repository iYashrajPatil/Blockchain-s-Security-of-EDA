# %%
import hashlib
import pandas as pd

def hash_dataset(file_path):
    df = pd.read_csv(file_path)
    df = df.reindex(sorted(df.columns), axis=1).sort_values(by=list(df.columns)).reset_index(drop=True)
    csv_bytes = df.to_csv(index=False).encode("utf-8")
    return hashlib.sha256(csv_bytes).hexdigest()

print(hash_dataset("Sales_data_Cleaned.csv"))
# Out:
# 4f4cd4c5979130269bef31d4c686b5c8f569aae7dd0ef1f955f40eaaa1a818e3

# %%
from web3 import Web3
import os

RPC_URL = os.getenv("https://eth-sepolia.g.alchemy.com/v2/d4Jb8rRLwNvXRjbOLh8xZ")
w3 = Web3(Web3.HTTPProvider("https://eth-sepolia.g.alchemy.com/v2/d4Jb8rRLwNvXRjbOLh8xZ"))

print("Connected:", w3.is_connected())
# Out:
# Connected: True

# %%
wallet="0xbe8360412a91e744efa1f213bdea7754326d48a2"
private="e59d96b7c07d3952186cf84dae6517ae48684473b4fd9642507abc10d3377aad"
contaddress="0x5c079dEE1A45BBb4D8D4BFae5F2718e5690D1b53"

# %%
import json
abi_json='''
[
	{
		"anonymous": false,
		"inputs": [
			{
				"indexed": false,
				"internalType": "string",
				"name": "datasetName",
				"type": "string"
			},
			{
				"indexed": false,
				"internalType": "string",
				"name": "hashValue",
				"type": "string"
			},
			{
				"indexed": true,
				"internalType": "address",
				"name": "by",
				"type": "address"
			},
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			}
		],
		"name": "HashStored",
		"type": "event"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "datasetName",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "hashValue",
				"type": "string"
			}
		],
		"name": "storeHash",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"name": "datasetHashes",
		"outputs": [
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "datasetName",
				"type": "string"
			}
		],
		"name": "getHash",
		"outputs": [
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
] '''

abi=json.loads(abi_json)

# %%
import pandas as pd
import hashlib

# Load your cleaned dataset
df = pd.read_csv("../data/Sales_data_Cleaned.csv")
# Deterministic hash function
def deterministic_hash_dataframe(df: pd.DataFrame) -> str:
    df2 = df.copy()
    # Sort columns and rows for consistency
    df2 = df2.reindex(sorted(df2.columns), axis=1)
    df2 = df2.sort_values(by=list(df2.columns)).reset_index(drop=True)
    # Convert to CSV bytes
    csv_bytes = df2.to_csv(index=False).encode("utf-8")
    return hashlib.sha256(csv_bytes).hexdigest()

dataset_hash = deterministic_hash_dataframe(df)
print("SHA-256 dataset fingerprint:", dataset_hash)
# Out:
# SHA-256 dataset fingerprint: adeb743c960f737a3cffb3d55c98eee39c6c331444e1736ac47cbcd0bc712cc2

# %%
pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

# Explicitly load secrets.env
load_dotenv("secrets.env")

# Access variables
WALLET_ADDRESS = os.getenv("WALLET_ADDRESS")
PRIVATE_KEY = os.getenv("PRIVATE_KEY")
RPC_URL = os.getenv("RPC_URL")
CONTRACT_ADDRESS = os.getenv("CONTRACT_ADDRESS")

print("Wallet:", WALLET_ADDRESS)
print("RPC URL:", RPC_URL)
# Out:
# Wallet: 0xbe8360412a91e744efa1f213bdea7754326d48a2
# RPC URL: https://eth-sepolia.g.alchemy.com/v2/d4Jb8rRLwNvXRjbOLh8xZ

# %%
# === Imports ===
import os, json, hashlib, pandas as pd
from web3 import Web3
from dotenv import load_dotenv

# === Load secrets ===
load_dotenv("secrets.env")

RPC_URL = os.getenv("RPC_URL")
PRIVATE_KEY = os.getenv("PRIVATE_KEY")

# Convert addresses to checksum format
WALLET_ADDRESS = Web3.to_checksum_address(os.getenv("WALLET_ADDRESS"))
CONTRACT_ADDRESS = Web3.to_checksum_address(os.getenv("CONTRACT_ADDRESS"))

# === Connect to Sepolia ===
w3 = Web3(Web3.HTTPProvider(RPC_URL))
print("Connected to Sepolia:", w3.is_connected())
print("Wallet:", WALLET_ADDRESS)
print("Contract:", CONTRACT_ADDRESS)

# === Load ABI (paste from Remix) ===
abi_json = '''
[
	{
		"anonymous": false,
		"inputs": [
			{
				"indexed": false,
				"internalType": "string",
				"name": "datasetName",
				"type": "string"
			},
			{
				"indexed": false,
				"internalType": "string",
				"name": "hashValue",
				"type": "string"
			},
			{
				"indexed": true,
				"internalType": "address",
				"name": "by",
				"type": "address"
			},
			{
				"indexed": false,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			}
		],
		"name": "HashStored",
		"type": "event"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "datasetName",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "hashValue",
				"type": "string"
			}
		],
		"name": "storeHash",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"name": "datasetHashes",
		"outputs": [
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "datasetName",
				"type": "string"
			}
		],
		"name": "getHash",
		"outputs": [
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]
'''
abi = json.loads(abi_json)

# Create contract object
contract = w3.eth.contract(address=CONTRACT_ADDRESS, abi=abi)

# === Step 3: Hash dataset ===
df = pd.read_csv("../data/Sales_data_Cleaned.csv")

def deterministic_hash_dataframe(df: pd.DataFrame) -> str:
    df2 = df.copy()
    df2 = df2.reindex(sorted(df2.columns), axis=1)
    df2 = df2.sort_values(by=list(df2.columns)).reset_index(drop=True)
    csv_bytes = df2.to_csv(index=False).encode("utf-8")
    return hashlib.sha256(csv_bytes).hexdigest()

dataset_hash = deterministic_hash_dataframe(df)
print("Dataset SHA-256 fingerprint:", dataset_hash)

# === Step 4: Anchor hash on-chain ===
def anchor_hash(dataset_name: str, hash_value: str):
    nonce = w3.eth.get_transaction_count(WALLET_ADDRESS)
    tx = contract.functions.storeHash(dataset_name, hash_value).build_transaction({
        "from": WALLET_ADDRESS,
        "nonce": nonce,
        "gas": 200000,
        "gasPrice": w3.to_wei("10", "gwei")
    })
    signed_tx = w3.eth.account.sign_transaction(tx, private_key=PRIVATE_KEY)

    # FIX: Web3.py v6 uses .raw_transaction
    raw_tx = getattr(signed_tx, "rawTransaction", None) or getattr(signed_tx, "raw_transaction", None)
    tx_hash = w3.eth.send_raw_transaction(raw_tx)

    receipt = w3.eth.wait_for_transaction_receipt(tx_hash)
    return receipt

def verify_hash(dataset_name: str, local_hash: str) -> bool:
    onchain_hash = contract.functions.getHash(dataset_name).call()
    print("On-chain hash:", onchain_hash)
    return onchain_hash == local_hash

# Anchor and verify
DATASET_NAME = "sales_data"
receipt = anchor_hash(DATASET_NAME, dataset_hash)
print("Anchored in tx:", receipt.transactionHash.hex())

verified = verify_hash(DATASET_NAME, dataset_hash)
print("Integrity verified:", verified)
# Out:
# Connected to Sepolia: True
# Wallet: 0xbE8360412A91e744efa1F213BdEA7754326d48a2
# Contract: 0x5c079dEE1A45BBb4D8D4BFae5F2718e5690D1b53
# Dataset SHA-256 fingerprint: adeb743c960f737a3cffb3d55c98eee39c6c331444e1736ac47cbcd0bc712cc2
# Anchored in tx: c612b9a426fe52e8580dd7ca92d63f2a85906afc97d5fa5a130a72a6e6f96a6b
# On-chain hash: adeb743c960f737a3cffb3d55c98eee39c6c331444e1736ac47cbcd0bc712cc2
# Integrity verified: True

# %%
# === Step 5: Tamper test ===
df_tampered = df.copy()
if not df_tampered.empty:
    first_num_col = next((c for c in df_tampered.columns if pd.api.types.is_numeric_dtype(df_tampered[c])), None)
    if first_num_col:
        df_tampered.loc[0, first_num_col] += 1  # change one value

tampered_hash = deterministic_hash_dataframe(df_tampered)
print("Tampered hash:", tampered_hash)
print("Tampered verification:", verify_hash(DATASET_NAME, tampered_hash))  # should be False
# Out:
# Tampered hash: e5f35258a67af71f099b63568ca2d684d8f527edf64ad92590782c146d4af3dc
# On-chain hash: adeb743c960f737a3cffb3d55c98eee39c6c331444e1736ac47cbcd0bc712cc2
# Tampered verification: False
